# %%
file_path = "../data/GSE5281_series_matrix.txt"

with open(file_path, "r", encoding="utf-8", errors="ignore") as f:
    for i in range(20):
        print(f.readline())
# Out:
# !Series_title	"Alzheimer's disease and the normal aged brain (steph-affy-human-433773)"
#
# !Series_geo_accession	"GSE5281"
#
# !Series_status	"Public on Jul 10 2006"
#
# !Series_submission_date	"Jul 10 2006"
#
# !Series_last_update_date	"Nov 08 2019"
#
# !Series_pubmed_id	"17077275"
#
# !Series_pubmed_id	"18332434"
#
# !Series_pubmed_id	"29937276"
#
# !Series_pubmed_id	"18270320"
#
# !Series_summary	"Information about the genes that are preferentially expressed during the course of Alzheimer’s disease (AD) could improve our understanding of the molecular mechanisms involved in the pathogenesis of this common cause of cognitive impairment in older persons, provide new opportunities in the diagnosis, early detection, and tracking of this disorder, and provide novel targets for the discovery of interventions to treat and prevent this disorder. Information about the genes that are preferentially expressed in relationship to normal neurological aging could provide new information about the molecular mechanisms that are involved in normal age-related cognitive decline and a host of age-related neurological disorders, and they could provide novel targets for the discovery of interventions to mitigate some of these deleterious effects."
#
# !Series_summary	"Aim 1. Collect brain samples from three Alzheimer’s Disease Centers (ADCs) for subsequent gene expression profiling. Individuals will be stratified with respect to diagnostic groups (using both clinical and neuropathological criteria), age groups, and APOE genotype. 150 individual brains will be sampled from the Arizona ADC, the Duke University ADC, and the Washington University ADC. Miniscule sample sizes (200 um of sectioned tissue) from six brain regions that are histopathologically or metabolically relevant to AD and aging will be collected, ensuring that this proposal does not deplete the national resource. Frozen and fixed samples will be sent to Phoenix, sectioned in a standardized fashion, and then returned. Aim 2. Tissue heterogeneity will be eliminated prior to expression profiling by performing laser capture microscopy on all brain regions. Aim 3. Expression profile LCM-captured cells on the Affymetrix U133 Plus 2.0 array (~55,000 transcripts), and quickly provide these data to the community at large. Aim 4. Identify pathogenic cascades related to each of the clinico-pathologic correlates using unsupervised and supervised analyses coupled with a hypothesis-driven approach. Aim 5. Validation of the expression correlates at the protein and functional levels."
#
# !Series_summary	"Scientific progress in the last few years has improved our understanding of AD and raised the hope of identifying treatments to halt the progression and prevent the onset of this disorder. For instance, researchers have begun to characterize the cascade of molecular events which lead to the major histopathological features of the disorder: neuritic plaques, which contain extra-cellular deposits of amyloid beta-peptides (Abeta); neurofibrillary tangles, which contain the hyperphosphorylated form of the intracellular, microtubule-associated protein, tau; and a loss of neurons and synapses. These molecular events provide targets for the development of promising new treatments. For example, A-beta has been postulated to trigger a cascade of events that are involved in the pathogenesis of AD. This proposal hopes to provide new information about the genes that are preferentially expressed in the development of AD histopathology, including the over-expression of APP, amyloid-induced neurotoxicity, and hyperphosphorylation of tau, as well as bring clarity to the metabolic abnormalities that seem to play a role in dementia and AD development and pathology."
#
# !Series_summary	"We will perform LCM on 6 brain regions with about 14 biological replicates per brain region.  The brain regions are as follows: 1) entorhinal cortex 2) hippocampus 3) medial temporal gyrus 4) posterior cingulate 5) superior frontal gyrus and 6) primary visual cortex.  We will collect layer III pyramidal cells from the white matter in each region, isolate total RNA from LCMed cell lysates, and perform double round amplification of each sample for array analysis."
#
# !Series_summary	"Keywords: other"
#
# !Series_type	"Expression profiling by array"
#
# !Series_contributor	"Dietrich,A,Stephan"
#
# !Series_contributor	"Winnie,S,Liang"
#
# !Series_sample_id	"GSM119615 GSM119616 GSM119617 GSM119618 GSM119619 GSM119620 GSM119621 GSM119622 GSM119623 GSM119624 GSM119625 GSM119626 GSM119627 GSM119628 GSM119629 GSM119630 GSM119631 GSM119632 GSM119633 GSM119634 GSM119635 GSM119636 GSM119637 GSM119638 GSM119639 GSM119640 GSM119641 GSM119642 GSM119643 GSM119644 GSM119645 GSM119646 GSM119647 GSM119648 GSM119649 GSM119650 GSM119651 GSM119652 GSM119653 GSM119654 GSM119655 GSM119656 GSM119657 GSM119658 GSM119659 GSM119660 GSM119661 GSM119662 GSM119663 GSM119664 GSM119665 GSM119666 GSM119667 GSM119668 GSM119669 GSM119670 GSM119671 GSM119672 GSM119673 GSM119674 GSM119675 GSM119676 GSM119677 GSM119678 GSM119679 GSM119680 GSM119681 GSM119682 GSM119683 GSM119684 GSM119685 GSM119686 GSM119687 GSM119688 GSM238763 GSM238790 GSM238791 GSM238792 GSM238793 GSM238794 GSM238795 GSM238796 GSM238797 GSM238798 GSM238799 GSM238800 GSM238801 GSM238802 GSM238803 GSM238804 GSM238805 GSM238806 GSM238807 GSM238808 GSM238809 GSM238810 GSM238811 GSM238812 GSM238813 GSM238815 GSM238816 GSM238817 GSM238818 GSM238819 GSM238820 GSM238821 GSM238822 GSM238823 GSM238824 GSM238825 GSM238826 GSM238827 GSM238834 GSM238835 GSM238837 GSM238838 GSM238839 GSM238840 GSM238841 GSM238842 GSM238843 GSM238844 GSM238845 GSM238846 GSM238847 GSM238848 GSM238851 GSM238854 GSM238855 GSM238856 GSM238857 GSM238858 GSM238860 GSM238861 GSM238862 GSM238863 GSM238864 GSM238865 GSM238867 GSM238868 GSM238870 GSM238871 GSM238872 GSM238873 GSM238874 GSM238875 GSM238877 GSM238941 GSM238942 GSM238943 GSM238944 GSM238945 GSM238946 GSM238947 GSM238948 GSM238949 GSM238951 GSM238952 GSM238953 GSM238955 GSM238963 "
#
# !Series_contact_name	"Winnie,,Liang"
#
# !Series_contact_email	"wliang@tgen.org"

# %%
file_path = "../data/GSE5281_series_matrix.txt"

with open(file_path, "r", encoding="utf-8", errors="ignore") as f:
    lines = f.readlines()

for i, line in enumerate(lines):
    if "ID_REF" in line:
        print("Found expression table at line:", i)
        print(line[:200])
        break
# Out:
# Found expression table at line: 80
# "ID_REF"	"GSM119615"	"GSM119616"	"GSM119617"	"GSM119618"	"GSM119619"	"GSM119620"	"GSM119621"	"GSM119622"	"GSM119623"	"GSM119624"	"GSM119625"	"GSM119626"	"GSM119627"	"GSM119628"	"GSM119629"	"GSM119630"

# %%
import pandas as pd

expression_data = pd.read_csv(
    "../data/GSE5281_series_matrix.txt",
    sep="\t",
    skiprows=80
)

expression_data.head()
# Out:
#       ID_REF   GSM119615   GSM119616    GSM119617    GSM119618   GSM119619  \
# 0  1007_s_at  693.973300  807.145140  1722.625000  1668.057500  2231.29690
# 1    1053_at    9.755318   19.052270    13.060389    14.652245   138.67683
# 2     117_at   13.346846   18.217276    97.425470    98.197945   106.46844
# 3     121_at  173.092450  289.315400   537.182800   496.346560   477.86517
# 4  1255_g_at   52.616950  110.375984    99.021736    17.306772   628.81616
#
#     GSM119620   GSM119621    GSM119622   GSM119623  ...  GSM238945  GSM238946  \
# 0  990.541000  1396.82420  1026.056500  736.770300  ...   983.1340   855.5980
# 1    7.186742    10.17089    34.056934    7.829473  ...    78.0901    57.5839
# 2   98.710520   164.32666    46.306164   35.067910  ...    35.8215   106.8380
# 3  355.092000   467.56790   294.583280  224.524060  ...   114.5470   174.5280
# 4  105.254600   142.26918   123.016136  183.396910  ...    18.8389    80.0143
#
#    GSM238947   GSM238948  GSM238949  GSM238951  GSM238952  GSM238953  \
# 0  2074.2300  1385.89000  1390.9400   904.4160  1319.0900   783.2270
# 1     4.9474    11.06460    78.2078    50.5737    13.7651    56.3892
# 2    87.6188    39.50480   117.6100    20.6184    31.4041    41.2217
# 3   180.7250   238.92100   221.8730   153.4310   262.5170   136.9680
# 4    69.0884     5.82269    44.7857    11.4650    30.3939    40.7314
#
#     GSM238955  GSM238963
# 0  1552.96000  2845.4500
# 1     6.97840    33.0147
# 2    40.48350    19.1316
# 3   284.89900   404.0750
# 4     4.34157    42.2666
#
# [5 rows x 162 columns]

# %%
expression_data.shape
# Out:
# (54676, 162)

# %%
expression_data.isnull().sum().sum()
# Out:
# np.int64(161)

# %%
expression_data.tail()
# Out:
#                          ID_REF   GSM119615  GSM119616  GSM119617  GSM119618  \
# 54671            AFFX-ThrX-M_at  279.892550   3.477558   6.315493  17.975550
# 54672           AFFX-TrpnX-3_at    9.149380   1.878478   8.501900   6.254964
# 54673           AFFX-TrpnX-5_at    5.280712   3.469311  23.347307  58.965458
# 54674           AFFX-TrpnX-M_at    7.380331   3.117868  67.153730   9.972722
# 54675  !series_matrix_table_end         NaN        NaN        NaN        NaN
#
#          GSM119619  GSM119620  GSM119621  GSM119622  GSM119623  ...  \
# 54671  3133.012200   7.277436  69.250970  27.650482  18.748734  ...
# 54672    29.297655   3.096380  10.467917   8.064908   8.410315  ...
# 54673    28.627400   5.922369  46.583836   7.823233  17.401910  ...
# 54674     2.507613   4.711027  10.538683   1.971074  18.304653  ...
# 54675          NaN        NaN        NaN        NaN        NaN  ...
#
#         GSM238945   GSM238946   GSM238947  GSM238948   GSM238949  GSM238951  \
# 54671  1642.06000  6853.23000  9776.78000  4727.5900  2344.04000  904.46400
# 54672     7.52713     2.75023    36.43110    67.1059     5.71708    4.60019
# 54673    26.46670    58.81460     7.31434    79.7225    57.59190    2.26764
# 54674    19.27290     4.38626    15.05010     8.4198     2.24515    1.99870
# 54675         NaN         NaN         NaN        NaN         NaN        NaN
#
#         GSM238952  GSM238953   GSM238955   GSM238963
# 54671  1809.77000  816.25200  3920.09000  3482.83000
# 54672     5.04322   14.44700    42.46360     7.63197
# 54673     6.63889    5.15024     7.38756    66.95930
# 54674     1.20378    1.31510    30.04950    52.17980
# 54675         NaN        NaN         NaN         NaN
#
# [5 rows x 162 columns]

# %%
expression_data = expression_data[
    expression_data["ID_REF"] != "!series_matrix_table_end"
]

expression_data.shape
# Out:
# (54675, 162)

# %%
expression_data.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
file_path = "../data/GSE5281_series_matrix.txt"

with open(file_path, "r", encoding="utf-8", errors="ignore") as f:
    lines = f.readlines()

for line in lines:
    if line.startswith("!Sample_title"):
        print(line[:1000])
        break
# Out:
# !Sample_title	"EC control 1"	"EC control 2"	"EC control 3"	"EC control 4"	"EC control 5"	"EC control 6"	"EC control 7"	"EC control 8"	"EC control 9"	"EC control 10"	"EC control 11"	"EC control 12"	"EC control 13"	"HIP control 1"	"HIP control 2"	"HIP control 3"	"HIP control 4"	"HIP control 5"	"HIP control 6"	"HIP control 7"	"HIP control 8"	"HIP control 9"	"HIP control 10"	"HIP control 11"	"HIP control 12"	"HIP control 13"	"MTG control 1"	"MTG control 2"	"MTG control 3"	"MTG control 4"	"MTG control 5"	"MTG control 6"	"MTG control 7"	"MTG control 8"	"MTG control 9"	"MTG control 10"	"MTG control 11"	"MTG control 12"	"PC control 1"	"PC control 2"	"PC control 3"	"PC control 4"	"PC control 5"	"PC control 6"	"PC control 7"	"PC control 8"	"PC control 9"	"PC control 10"	"PC control 11"	"PC control 12"	"PC control 13"	"SFG control 1"	"SFG control 2"	"SFG control 3"	"SFG control 4"	"SFG control 5"	"SFG control 6"	"SFG control 7"	"SFG control 8"	"SFG control 9"	"SFG control 10"	"SFG control 11"	"VC

# %%
for line in lines:
    if line.startswith("!Sample_source_name_ch1"):
        print(line[:1000])
        break
# Out:
# !Sample_source_name_ch1	"brain, Entorhinal Cortex"	"brain, Entorhinal Cortex"	"brain, Entorhinal Cortex"	"brain, Entorhinal Cortex"	"brain, Entorhinal Cortex"	"brain, Entorhinal Cortex"	"brain, Entorhinal Cortex"	"brain, Entorhinal Cortex"	"brain, Entorhinal Cortex"	"brain, Entorhinal Cortex"	"brain, Entorhinal Cortex"	"brain, Entorhinal Cortex"	"brain, Entorhinal Cortex"	"brain, hippocampus"	"brain, hippocampus"	"brain, hippocampus"	"brain, hippocampus"	"brain, hippocampus"	"brain, hippocampus"	"brain, hippocampus"	"brain, hippocampus"	"brain, hippocampus"	"brain, hippocampus"	"brain, hippocampus"	"brain, hippocampus"	"brain, hippocampus"	"brain, Medial Temporal Gyrus"	"brain, Medial Temporal Gyrus"	"brain, Medial Temporal Gyrus"	"brain, Medial Temporal Gyrus"	"brain, Medial Temporal Gyrus"	"brain, Medial Temporal Gyrus"	"brain, Medial Temporal Gyrus"	"brain, Medial Temporal Gyrus"	"brain, Medial Temporal Gyrus"	"brain, Medial Temporal Gyrus"	"brain, Medial Temporal Gyrus"	"brain, Med

# %%
for line in lines:
    if line.startswith("!Sample_characteristics_ch1"):
        print(line[:1000])
        break
# Out:
# !Sample_characteristics_ch1	"Sample Amount: 10 ug"	"Sample Amount: 10 ug"	"Sample Amount: 10 ug"	"Sample Amount: 10 ug"	"Sample Amount: 10 ug"	"Sample Amount: 10 ug"	"Sample Amount: 10 ug"	"Sample Amount: 10 ug"	"Sample Amount: 10 ug"	"Sample Amount: 10 ug"	"Sample Amount: 10 ug"	"Sample Amount: 10 ug"	"Sample Amount: 10 ug"	"Sample Amount: 10 ug"	"Sample Amount: 10 ug"	"Sample Amount: 10 ug"	"Sample Amount: 10 ug"	"Sample Amount: 10 ug"	"Sample Amount: 10 ug"	"Sample Amount: 10 ug"	"Sample Amount: 10 ug"	"Sample Amount: 10 ug"	"Sample Amount: 10 ug"	"Sample Amount: 10 ug"	"Sample Amount: 10 ug"	"Sample Amount: 10 ug"	"Sample Amount: 10 ug"	"Sample Amount: 10 ug"	"Sample Amount: 10 ug"	"Sample Amount: 10 ug"	"Sample Amount: 10 ug"	"Sample Amount: 10 ug"	"Sample Amount: 10 ug"	"Sample Amount: 10 ug"	"Sample Amount: 10 ug"	"Sample Amount: 10 ug"	"Sample Amount: 10 ug"	"Sample Amount: 10 ug"	"sample amount: 10 ug"	"sample amount: 10 ug"	"sample amount: 10 ug"	"sample amount: 10 ug"	"sampl

# %%
for line in lines:
    if line.startswith("!Sample_title"):
        print(line)
        break
# Out:
# !Sample_title	"EC control 1"	"EC control 2"	"EC control 3"	"EC control 4"	"EC control 5"	"EC control 6"	"EC control 7"	"EC control 8"	"EC control 9"	"EC control 10"	"EC control 11"	"EC control 12"	"EC control 13"	"HIP control 1"	"HIP control 2"	"HIP control 3"	"HIP control 4"	"HIP control 5"	"HIP control 6"	"HIP control 7"	"HIP control 8"	"HIP control 9"	"HIP control 10"	"HIP control 11"	"HIP control 12"	"HIP control 13"	"MTG control 1"	"MTG control 2"	"MTG control 3"	"MTG control 4"	"MTG control 5"	"MTG control 6"	"MTG control 7"	"MTG control 8"	"MTG control 9"	"MTG control 10"	"MTG control 11"	"MTG control 12"	"PC control 1"	"PC control 2"	"PC control 3"	"PC control 4"	"PC control 5"	"PC control 6"	"PC control 7"	"PC control 8"	"PC control 9"	"PC control 10"	"PC control 11"	"PC control 12"	"PC control 13"	"SFG control 1"	"SFG control 2"	"SFG control 3"	"SFG control 4"	"SFG control 5"	"SFG control 6"	"SFG control 7"	"SFG control 8"	"SFG control 9"	"SFG control 10"	"SFG control 11"	"VCX control 1"	"VCX control 2"	"VCX control 3"	"VCX control 4"	"VCX control 5"	"VCX control 6"	"VCX control 7"	"VCX control 8"	"VCX control 9"	"VCX control 10"	"VCX control 11"	"VCX control 12"	"EC_affected_1"	"EC_affected_2"	"EC_affected_3"	"EC_affected_4"	"EC_affected_5"	"EC_affected_6"	"EC_affected_7"	"EC_affected_8"	"EC_affected_9"	"EC_affected_10"	"HIP_affected_1"	"HIP_affected_2"	"HIP_affected_3"	"HIP_affected_4"	"HIP_affected_5"	"HIP_affected_6"	"HIP_affected_7"	"HIP_affected_8"	"HIP_affected_9"	"HIP_affected_10"	"MTG_affected_1"	"MTG_affected_2"	"MTG_affected_3"	"MTG_affected_4"	"MTG_affected_5"	"MTG_affected_6"	"MTG_affected_7"	"MTG_affected_8"	"MTG_affected_9"	"MTG_affected_10"	"MTG_affected_11"	"MTG_affected_12"	"MTG_affected_13"	"MTG_affected_14"	"MTG_affected_15"	"MTG_affected_16"	"PC_affected_1"	"PC_affected_2"	"PC_affected_3"	"PC_affected_4"	"PC_affected_5"	"PC_affected_6"	"PC_affected_7"	"PC_affected_8"	"PC_affected_9"	"SFG_affected_1"	"SFG_affected_2"	"SFG_affected_3"	"SFG_affected_4"	"SFG_affected_5"	"SFG_affected_6"	"SFG_affected_7"	"SFG_affected_8"	"SFG_affected_9"	"SFG_affected_10"	"SFG_affected_11"	"SFG_affected_12"	"SFG_affected_13"	"SFG_affected_14"	"SFG_affected_15"	"SFG_affected_16"	"SFG_affected_17"	"SFG_affected_18"	"SFG_affected_19"	"SFG_affected_20"	"SFG_affected_21"	"SFG_affected_22"	"SFG_affected_23"	"VCX_affected_1"	"VCX_affected_2"	"VCX_affected_3"	"VCX_affected_4"	"VCX_affected_5"	"VCX_affected_6"	"VCX_affected_7"	"VCX_affected_8"	"VCX_affected_9"	"VCX_affected_10"	"VCX_affected_11"	"VCX_affected_12"	"VCX_affected_13"	"VCX_affected_14"	"VCX_affected_15"	"VCX_affected_16"	"VCX_affected_17"	"VCX_affected_18"	"VCX_affected_19"

# %%
sample_names = expression_data.columns[1:]

phenotype = []

for sample in sample_names:
    phenotype.append({
        "Sample": sample
    })

import pandas as pd

phenotype = pd.DataFrame(phenotype)

phenotype.head()
# Out:
#       Sample
# 0  GSM119615
# 1  GSM119616
# 2  GSM119617
# 3  GSM119618
# 4  GSM119619

# %%
for line in lines:
    if line.startswith("!Sample_title"):
        titles = line.strip().split("\t")[1:]
        break

disease_status = []

for title in titles:

    title = title.replace('"', '')

    if "control" in title.lower():
        disease_status.append("Control")
    elif "affected" in title.lower():
        disease_status.append("Alzheimer")
    else:
        disease_status.append("Unknown")

phenotype["Title"] = [t.replace('"','') for t in titles]
phenotype["Disease"] = disease_status

phenotype.head()
# Out:
#       Sample         Title  Disease
# 0  GSM119615  EC control 1  Control
# 1  GSM119616  EC control 2  Control
# 2  GSM119617  EC control 3  Control
# 3  GSM119618  EC control 4  Control
# 4  GSM119619  EC control 5  Control

# %%
phenotype["Disease"].value_counts()
# Out:
# Disease
# Alzheimer    87
# Control      74
# Name: count, dtype: int64

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

X = expression_data.drop(columns=["ID_REF"])

X = X.T

print(X.shape)
# Out:
# (161, 54675)

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

X = expression_data.drop(columns=["ID_REF"])

X = X.T

print(X.shape)
# Out:
# (161, 54675)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

print(X_scaled.shape)
# Out:
# (161, 54675)

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)

X_pca = pca.fit_transform(X_scaled)

print(X_pca.shape)

print("Explained variance ratio:")
print(pca.explained_variance_ratio_)
# Out:
# (161, 2)
# Explained variance ratio:
# [0.16986123 0.13762485]

# %%
import matplotlib.pyplot as plt

pca_df = pd.DataFrame({
    "PC1": X_pca[:, 0],
    "PC2": X_pca[:, 1],
    "Disease": phenotype["Disease"]
})

plt.figure(figsize=(8,6))

for disease in pca_df["Disease"].unique():
    subset = pca_df[pca_df["Disease"] == disease]

    plt.scatter(
        subset["PC1"],
        subset["PC2"],
        label=disease
    )

plt.xlabel("PC1")
plt.ylabel("PC2")
plt.title("PCA of Alzheimer's Gene Expression Dataset")
plt.legend()

plt.show()

# %%
regions = []

for title in phenotype["Title"]:

    if title.startswith("EC"):
        regions.append("EC")
    elif title.startswith("HIP"):
        regions.append("HIP")
    elif title.startswith("MTG"):
        regions.append("MTG")
    elif title.startswith("PC"):
        regions.append("PC")
    elif title.startswith("SFG"):
        regions.append("SFG")
    elif title.startswith("VCX"):
        regions.append("VCX")
    else:
        regions.append("Unknown")

phenotype["Region"] = regions

phenotype.head()
# Out:
#       Sample         Title  Disease Region
# 0  GSM119615  EC control 1  Control     EC
# 1  GSM119616  EC control 2  Control     EC
# 2  GSM119617  EC control 3  Control     EC
# 3  GSM119618  EC control 4  Control     EC
# 4  GSM119619  EC control 5  Control     EC

# %%
phenotype["Region"].value_counts()
# Out:
# Region
# SFG    34
# VCX    31
# MTG    28
# EC     23
# HIP    23
# PC     22
# Name: count, dtype: int64

# %%
ec_samples = phenotype[phenotype["Region"] == "EC"]

print(ec_samples.shape)

ec_samples.head()
# Out:
# (23, 4)
#       Sample         Title  Disease Region
# 0  GSM119615  EC control 1  Control     EC
# 1  GSM119616  EC control 2  Control     EC
# 2  GSM119617  EC control 3  Control     EC
# 3  GSM119618  EC control 4  Control     EC
# 4  GSM119619  EC control 5  Control     EC

# %%
ec_samples["Disease"].value_counts()
# Out:
# Disease
# Control      13
# Alzheimer    10
# Name: count, dtype: int64

# %%
ec_sample_ids = ec_samples["Sample"].tolist()

ec_expression = expression_data[
    ["ID_REF"] + ec_sample_ids
]

ec_expression.shape
# Out:
# (54675, 24)

# %%
ec_expression.head()
# Out:
#       ID_REF   GSM119615   GSM119616    GSM119617    GSM119618   GSM119619  \
# 0  1007_s_at  693.973300  807.145140  1722.625000  1668.057500  2231.29690
# 1    1053_at    9.755318   19.052270    13.060389    14.652245   138.67683
# 2     117_at   13.346846   18.217276    97.425470    98.197945   106.46844
# 3     121_at  173.092450  289.315400   537.182800   496.346560   477.86517
# 4  1255_g_at   52.616950  110.375984    99.021736    17.306772   628.81616
#
#     GSM119620   GSM119621    GSM119622   GSM119623  ...   GSM238763  \
# 0  990.541000  1396.82420  1026.056500  736.770300  ...  1085.67000
# 1    7.186742    10.17089    34.056934    7.829473  ...     7.33548
# 2   98.710520   164.32666    46.306164   35.067910  ...   133.62600
# 3  355.092000   467.56790   294.583280  224.524060  ...   521.51900
# 4  105.254600   142.26918   123.016136  183.396910  ...    86.91590
#
#    GSM238790  GSM238791   GSM238792  GSM238793  GSM238794  GSM238795  \
# 0   479.4800  2104.8300  1521.09000  1492.1300  1874.3600  1572.3700
# 1    57.5863    10.5687     9.49972    10.6124    10.7383    27.0712
# 2    20.8386    65.9487    88.68500    81.3545   161.2070    80.2923
# 3    89.6319   777.7550   387.39200   479.7910   707.4530   615.5590
# 4    51.6461    44.4397    49.32680    47.2470    95.6610    41.1387
#
#    GSM238796   GSM238797   GSM238798
# 0  3079.9600  2053.03000  2347.20000
# 1    20.8748     6.52817     9.45628
# 2    49.2970   108.58900    96.80220
# 3   903.2000   579.92900   604.25900
# 4    26.2126   100.82600    62.98280
#
# [5 rows x 24 columns]

# %%
control_ids = ec_samples[
    ec_samples["Disease"] == "Control"
]["Sample"].tolist()

alz_ids = ec_samples[
    ec_samples["Disease"] == "Alzheimer"
]["Sample"].tolist()

print("Controls:", len(control_ids))
print("Alzheimer:", len(alz_ids))
# Out:
# Controls: 13
# Alzheimer: 10

# %%
gene_stats = pd.DataFrame()

gene_stats["Gene"] = ec_expression["ID_REF"]

gene_stats["Control_Mean"] = ec_expression[
    control_ids
].mean(axis=1)

gene_stats["Alzheimer_Mean"] = ec_expression[
    alz_ids
].mean(axis=1)

gene_stats.head()
# Out:
#         Gene  Control_Mean  Alzheimer_Mean
# 0  1007_s_at   1111.143959     1761.012000
# 1    1053_at     32.877695       17.027135
# 2     117_at     77.381416       88.664030
# 3     121_at    358.452262      566.648890
# 4  1255_g_at    152.446415       60.639660

# %%
import numpy as np

gene_stats["Log2FC"] = np.log2(
    (gene_stats["Alzheimer_Mean"] + 1) /
    (gene_stats["Control_Mean"] + 1)
)

gene_stats.head()
# Out:
#         Gene  Control_Mean  Alzheimer_Mean    Log2FC
# 0  1007_s_at   1111.143959     1761.012000  0.663880
# 1    1053_at     32.877695       17.027135 -0.910166
# 2     117_at     77.381416       88.664030  0.194018
# 3     121_at    358.452262      566.648890  0.659199
# 4  1255_g_at    152.446415       60.639660 -1.315804

# %%
gene_stats.sort_values(
    "Log2FC",
    ascending=False
).head(20)
# Out:
#                Gene  Control_Mean  Alzheimer_Mean    Log2FC
# 36317     227062_at    217.892718     3310.222400  3.919068
# 34496     225239_at    205.077283     3102.490000  3.912634
# 44462     235213_at     74.661298     1043.193170  3.786689
# 9617   1570078_a_at      9.961385      139.575880  3.680847
# 20809     211481_at     38.866507      457.746460  3.524448
# 45688     236439_at     90.150018     1044.956630  3.520436
# 32338   223059_s_at    290.183699     3199.101800  3.458116
# 113      1552411_at     21.896960      224.696010  3.301153
# 43680     234431_at     63.438684      590.284640  3.197854
# 22892     213592_at     97.680450      881.728300  3.161133
# 47974     238725_at      7.396993       69.721850  3.074211
# 12952     203505_at    272.862112     2141.846400  2.968007
# 10609   201161_s_at     11.227269       94.551705  2.966179
# 33062     223786_at      7.845215       67.107363  2.944842
# 44786     235537_at     39.109900      307.197840  2.941826
# 34773     225516_at     68.851188      522.079570  2.904674
# 40831   231577_s_at     48.118726      362.399720  2.887212
# 817      1553392_at      9.867437       78.189292  2.865294
# 21369     212063_at     59.035617      434.555500  2.858966
# 31844   222565_s_at     17.882372      134.833770  2.846730

# %%
from scipy.stats import ttest_ind

p_values = []

for _, row in ec_expression.iterrows():

    control_values = row[control_ids]
    alz_values = row[alz_ids]

    _, p = ttest_ind(
        control_values,
        alz_values,
        equal_var=False
    )

    p_values.append(p)

gene_stats["p_value"] = p_values

gene_stats.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\Desktop\AI Alzheimers Biomarker Discovery\alz_ai\Lib\site-packages\scipy\_lib\array_api_compat\common\_aliases.py:649, in finfo(type_, xp)
#     648 try:
# --> 649     return xp.finfo(type_)
#     650 except (ValueError, TypeError):
#
# File ~\Desktop\AI Alzheimers Biomarker Discovery\alz_ai\Lib\site-packages\numpy\_core\getlimits.py:210, in finfo.__new__(cls, dtype)
#     209 if not issubclass(dtype, numeric.inexact):
# --> 210     raise ValueError(f"data type {dtype!r} not inexact")
#     211 obj = cls._finfo_cache.get(dtype)
#
# ValueError: data type <class 'numpy.object_'> not inexact
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 10
#       6
#       7     control_values = row[control_ids]
#       8     alz_values = row[alz_ids]
#       9
# ---> 10     _, p = ttest_ind(
#      11         control_values,
#      12         alz_values,
#      13         equal_var=False
#
# File ~\Desktop\AI Alzheimers Biomarker Discovery\alz_ai\Lib\site-packages\scipy\stats\_axis_nan_policy.py:592, in _axis_nan_policy_factory.<locals>.axis_nan_policy_decorator.<locals>.axis_nan_policy_wrapper(***failed resolving arguments***)
#     589     res = _add_reduced_axes(res, reduced_axes, keepdims)
#     590     return tuple_to_result(*res)
# --> 592 res = hypotest_fun_out(*samples, **kwds)
#     593 res = result_to_tuple(res, n_out)
#     594 res = _add_reduced_axes(res, reduced_axes, keepdims)
#
# File ~\Desktop\AI Alzheimers Biomarker Discovery\alz_ai\Lib\site-packages\scipy\stats\_stats_py.py:6736, in ttest_ind(a, b, axis, equal_var, nan_policy, alternative, trim, method)
#    6732     n2 = _length_nonmasked(b, axis)
#    6733
#    6734     if trim == 0:
#    6735         with np.errstate(divide='ignore', invalid='ignore'):
# -> 6736             v1 = _var(a, axis, ddof=1, xp=xp)
#    6737             v2 = _var(b, axis, ddof=1, xp=xp)
#    6738
#    6739         m1 = xp.mean(a, axis=axis)
#
# File ~\Desktop\AI Alzheimers Biomarker Discovery\alz_ai\Lib\site-packages\scipy\stats\_stats_py.py:1247, in _var(x, axis, ddof, mean, xp)
#    1244 def _var(x, axis=0, ddof=0, mean=None, xp=None):
#    1245     # Calculate variance of sample, warning if precision is lost
#    1246     xp = array_namespace(x) if xp is None else xp
# -> 1247     var = _moment(x, 2, axis, mean=mean, xp=xp)
#    1248     if ddof != 0:
#    1249         n = _length_nonmasked(x, axis, xp=xp)
#    1250         n = xp.asarray(n, dtype=x.dtype, device=xp_device(x))
#
# File ~\Desktop\AI Alzheimers Biomarker Discovery\alz_ai\Lib\site-packages\scipy\stats\_stats_py.py:1229, in _moment(a, order, axis, mean, xp)
#    1225     # Starting point for exponentiation by squares
#    1226     mean = (xp.mean(a, axis=axis, keepdims=True) if mean is None
#    1227             else xp.asarray(mean, dtype=dtype))
#    1228     mean = mean[()] if mean.ndim == 0 else mean
# -> 1229     a_zero_mean = _demean(a, mean, axis, xp=xp)
#    1230
#    1231     if n_list[-1] == 1:
#    1232         s = xp.asarray(a_zero_mean, copy=True)
#
# File ~\Desktop\AI Alzheimers Biomarker Discovery\alz_ai\Lib\site-packages\scipy\stats\_stats_py.py:1168, in _demean(a, mean, axis, xp, precision_warning)
#    1164     if (xp_size(a_zero_mean) == 0 or not precision_warning
#    1165         or is_lazy_array(a_zero_mean)):
#    1166         return a_zero_mean
#    1167
# -> 1168     eps = xp.finfo(mean.dtype).eps * 10
#    1169
#    1170     with np.errstate(divide='ignore', invalid='ignore'):
#    1171         rel_diff = xp.max(xp.abs(a_zero_mean), axis=axis,
#
# File ~\Desktop\AI Alzheimers Biomarker Discovery\alz_ai\Lib\site-packages\scipy\_lib\array_api_compat\_internal.py:35, in get_xp.<locals>.inner.<locals>.wrapped_f(*args, **kwargs)
#      33 @wraps(f)
#      34 def wrapped_f(*args: object, **kwargs: object) -> object:
# ---> 35     return f(*args, xp=xp, **kwargs)
#
# File ~\Desktop\AI Alzheimers Biomarker Discovery\alz_ai\Lib\site-packages\scipy\_lib\array_api_compat\common\_aliases.py:651, in finfo(type_, xp)
#     649     return xp.finfo(type_)
#     650 except (ValueError, TypeError):
# --> 651     return xp.finfo(type_.dtype)
#
# AttributeError: 'numpy.dtypes.ObjectDType' object has no attribute 'dtype'

# %%
ec_expression.dtypes.head()
# Out:
# ID_REF           str
# GSM119615    float64
# GSM119616    float64
# GSM119617    float64
# GSM119618    float64
# dtype: object

# %%
ec_expression.iloc[:,1:].dtypes.unique()
# Out:
# array([dtype('float64')], dtype=object)

# %%
ec_expression_numeric = ec_expression.copy()

for col in ec_expression_numeric.columns[1:]:
    ec_expression_numeric[col] = pd.to_numeric(
        ec_expression_numeric[col],
        errors="coerce"
    )

ec_expression_numeric.iloc[:,1:].dtypes.unique()
# Out:
# array([dtype('float64')], dtype=object)

# %%
gene_stats = pd.DataFrame()

gene_stats["Gene"] = ec_expression_numeric["ID_REF"]

gene_stats["Control_Mean"] = ec_expression_numeric[
    control_ids
].mean(axis=1)

gene_stats["Alzheimer_Mean"] = ec_expression_numeric[
    alz_ids
].mean(axis=1)

import numpy as np

gene_stats["Log2FC"] = np.log2(
    (gene_stats["Alzheimer_Mean"] + 1) /
    (gene_stats["Control_Mean"] + 1)
)

# %%
from scipy.stats import ttest_ind

p_values = []

for _, row in ec_expression_numeric.iterrows():

    control_values = row[control_ids]
    alz_values = row[alz_ids]

    _, p = ttest_ind(
        control_values,
        alz_values,
        equal_var=False
    )

    p_values.append(p)

gene_stats["p_value"] = p_values
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\Desktop\AI Alzheimers Biomarker Discovery\alz_ai\Lib\site-packages\scipy\_lib\array_api_compat\common\_aliases.py:649, in finfo(type_, xp)
#     648 try:
# --> 649     return xp.finfo(type_)
#     650 except (ValueError, TypeError):
#
# File ~\Desktop\AI Alzheimers Biomarker Discovery\alz_ai\Lib\site-packages\numpy\_core\getlimits.py:210, in finfo.__new__(cls, dtype)
#     209 if not issubclass(dtype, numeric.inexact):
# --> 210     raise ValueError(f"data type {dtype!r} not inexact")
#     211 obj = cls._finfo_cache.get(dtype)
#
# ValueError: data type <class 'numpy.object_'> not inexact
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 10
#       6
#       7     control_values = row[control_ids]
#       8     alz_values = row[alz_ids]
#       9
# ---> 10     _, p = ttest_ind(
#      11         control_values,
#      12         alz_values,
#      13         equal_var=False
#
# File ~\Desktop\AI Alzheimers Biomarker Discovery\alz_ai\Lib\site-packages\scipy\stats\_axis_nan_policy.py:592, in _axis_nan_policy_factory.<locals>.axis_nan_policy_decorator.<locals>.axis_nan_policy_wrapper(***failed resolving arguments***)
#     589     res = _add_reduced_axes(res, reduced_axes, keepdims)
#     590     return tuple_to_result(*res)
# --> 592 res = hypotest_fun_out(*samples, **kwds)
#     593 res = result_to_tuple(res, n_out)
#     594 res = _add_reduced_axes(res, reduced_axes, keepdims)
#
# File ~\Desktop\AI Alzheimers Biomarker Discovery\alz_ai\Lib\site-packages\scipy\stats\_stats_py.py:6736, in ttest_ind(a, b, axis, equal_var, nan_policy, alternative, trim, method)
#    6732     n2 = _length_nonmasked(b, axis)
#    6733
#    6734     if trim == 0:
#    6735         with np.errstate(divide='ignore', invalid='ignore'):
# -> 6736             v1 = _var(a, axis, ddof=1, xp=xp)
#    6737             v2 = _var(b, axis, ddof=1, xp=xp)
#    6738
#    6739         m1 = xp.mean(a, axis=axis)
#
# File ~\Desktop\AI Alzheimers Biomarker Discovery\alz_ai\Lib\site-packages\scipy\stats\_stats_py.py:1247, in _var(x, axis, ddof, mean, xp)
#    1244 def _var(x, axis=0, ddof=0, mean=None, xp=None):
#    1245     # Calculate variance of sample, warning if precision is lost
#    1246     xp = array_namespace(x) if xp is None else xp
# -> 1247     var = _moment(x, 2, axis, mean=mean, xp=xp)
#    1248     if ddof != 0:
#    1249         n = _length_nonmasked(x, axis, xp=xp)
#    1250         n = xp.asarray(n, dtype=x.dtype, device=xp_device(x))
#
# File ~\Desktop\AI Alzheimers Biomarker Discovery\alz_ai\Lib\site-packages\scipy\stats\_stats_py.py:1229, in _moment(a, order, axis, mean, xp)
#    1225     # Starting point for exponentiation by squares
#    1226     mean = (xp.mean(a, axis=axis, keepdims=True) if mean is None
#    1227             else xp.asarray(mean, dtype=dtype))
#    1228     mean = mean[()] if mean.ndim == 0 else mean
# -> 1229     a_zero_mean = _demean(a, mean, axis, xp=xp)
#    1230
#    1231     if n_list[-1] == 1:
#    1232         s = xp.asarray(a_zero_mean, copy=True)
#
# File ~\Desktop\AI Alzheimers Biomarker Discovery\alz_ai\Lib\site-packages\scipy\stats\_stats_py.py:1168, in _demean(a, mean, axis, xp, precision_warning)
#    1164     if (xp_size(a_zero_mean) == 0 or not precision_warning
#    1165         or is_lazy_array(a_zero_mean)):
#    1166         return a_zero_mean
#    1167
# -> 1168     eps = xp.finfo(mean.dtype).eps * 10
#    1169
#    1170     with np.errstate(divide='ignore', invalid='ignore'):
#    1171         rel_diff = xp.max(xp.abs(a_zero_mean), axis=axis,
#
# File ~\Desktop\AI Alzheimers Biomarker Discovery\alz_ai\Lib\site-packages\scipy\_lib\array_api_compat\_internal.py:35, in get_xp.<locals>.inner.<locals>.wrapped_f(*args, **kwargs)
#      33 @wraps(f)
#      34 def wrapped_f(*args: object, **kwargs: object) -> object:
# ---> 35     return f(*args, xp=xp, **kwargs)
#
# File ~\Desktop\AI Alzheimers Biomarker Discovery\alz_ai\Lib\site-packages\scipy\_lib\array_api_compat\common\_aliases.py:651, in finfo(type_, xp)
#     649     return xp.finfo(type_)
#     650 except (ValueError, TypeError):
# --> 651     return xp.finfo(type_.dtype)
#
# AttributeError: 'numpy.dtypes.ObjectDType' object has no attribute 'dtype'

# %%
gene_stats = pd.DataFrame()

gene_stats["Gene"] = ec_expression_numeric["ID_REF"]

gene_stats["Control_Mean"] = ec_expression_numeric[
    control_ids
].mean(axis=1)

gene_stats["Alzheimer_Mean"] = ec_expression_numeric[
    alz_ids
].mean(axis=1)

import numpy as np

gene_stats["Log2FC"] = np.log2(
    (gene_stats["Alzheimer_Mean"] + 1) /
    (gene_stats["Control_Mean"] + 1)
)

# %%
from scipy.stats import ttest_ind

p_values = []

for _, row in ec_expression_numeric.iterrows():

    control_values = row[control_ids]
    alz_values = row[alz_ids]

    _, p = ttest_ind(
        control_values,
        alz_values,
        equal_var=False
    )

    p_values.append(p)

gene_stats["p_value"] = p_values
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\Desktop\AI Alzheimers Biomarker Discovery\alz_ai\Lib\site-packages\scipy\_lib\array_api_compat\common\_aliases.py:649, in finfo(type_, xp)
#     648 try:
# --> 649     return xp.finfo(type_)
#     650 except (ValueError, TypeError):
#
# File ~\Desktop\AI Alzheimers Biomarker Discovery\alz_ai\Lib\site-packages\numpy\_core\getlimits.py:210, in finfo.__new__(cls, dtype)
#     209 if not issubclass(dtype, numeric.inexact):
# --> 210     raise ValueError(f"data type {dtype!r} not inexact")
#     211 obj = cls._finfo_cache.get(dtype)
#
# ValueError: data type <class 'numpy.object_'> not inexact
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[40], line 10
#       6
#       7     control_values = row[control_ids]
#       8     alz_values = row[alz_ids]
#       9
# ---> 10     _, p = ttest_ind(
#      11         control_values,
#      12         alz_values,
#      13         equal_var=False
#
# File ~\Desktop\AI Alzheimers Biomarker Discovery\alz_ai\Lib\site-packages\scipy\stats\_axis_nan_policy.py:592, in _axis_nan_policy_factory.<locals>.axis_nan_policy_decorator.<locals>.axis_nan_policy_wrapper(***failed resolving arguments***)
#     589     res = _add_reduced_axes(res, reduced_axes, keepdims)
#     590     return tuple_to_result(*res)
# --> 592 res = hypotest_fun_out(*samples, **kwds)
#     593 res = result_to_tuple(res, n_out)
#     594 res = _add_reduced_axes(res, reduced_axes, keepdims)
#
# File ~\Desktop\AI Alzheimers Biomarker Discovery\alz_ai\Lib\site-packages\scipy\stats\_stats_py.py:6736, in ttest_ind(a, b, axis, equal_var, nan_policy, alternative, trim, method)
#    6732     n2 = _length_nonmasked(b, axis)
#    6733
#    6734     if trim == 0:
#    6735         with np.errstate(divide='ignore', invalid='ignore'):
# -> 6736             v1 = _var(a, axis, ddof=1, xp=xp)
#    6737             v2 = _var(b, axis, ddof=1, xp=xp)
#    6738
#    6739         m1 = xp.mean(a, axis=axis)
#
# File ~\Desktop\AI Alzheimers Biomarker Discovery\alz_ai\Lib\site-packages\scipy\stats\_stats_py.py:1247, in _var(x, axis, ddof, mean, xp)
#    1244 def _var(x, axis=0, ddof=0, mean=None, xp=None):
#    1245     # Calculate variance of sample, warning if precision is lost
#    1246     xp = array_namespace(x) if xp is None else xp
# -> 1247     var = _moment(x, 2, axis, mean=mean, xp=xp)
#    1248     if ddof != 0:
#    1249         n = _length_nonmasked(x, axis, xp=xp)
#    1250         n = xp.asarray(n, dtype=x.dtype, device=xp_device(x))
#
# File ~\Desktop\AI Alzheimers Biomarker Discovery\alz_ai\Lib\site-packages\scipy\stats\_stats_py.py:1229, in _moment(a, order, axis, mean, xp)
#    1225     # Starting point for exponentiation by squares
#    1226     mean = (xp.mean(a, axis=axis, keepdims=True) if mean is None
#    1227             else xp.asarray(mean, dtype=dtype))
#    1228     mean = mean[()] if mean.ndim == 0 else mean
# -> 1229     a_zero_mean = _demean(a, mean, axis, xp=xp)
#    1230
#    1231     if n_list[-1] == 1:
#    1232         s = xp.asarray(a_zero_mean, copy=True)
#
# File ~\Desktop\AI Alzheimers Biomarker Discovery\alz_ai\Lib\site-packages\scipy\stats\_stats_py.py:1168, in _demean(a, mean, axis, xp, precision_warning)
#    1164     if (xp_size(a_zero_mean) == 0 or not precision_warning
#    1165         or is_lazy_array(a_zero_mean)):
#    1166         return a_zero_mean
#    1167
# -> 1168     eps = xp.finfo(mean.dtype).eps * 10
#    1169
#    1170     with np.errstate(divide='ignore', invalid='ignore'):
#    1171         rel_diff = xp.max(xp.abs(a_zero_mean), axis=axis,
#
# File ~\Desktop\AI Alzheimers Biomarker Discovery\alz_ai\Lib\site-packages\scipy\_lib\array_api_compat\_internal.py:35, in get_xp.<locals>.inner.<locals>.wrapped_f(*args, **kwargs)
#      33 @wraps(f)
#      34 def wrapped_f(*args: object, **kwargs: object) -> object:
# ---> 35     return f(*args, xp=xp, **kwargs)
#
# File ~\Desktop\AI Alzheimers Biomarker Discovery\alz_ai\Lib\site-packages\scipy\_lib\array_api_compat\common\_aliases.py:651, in finfo(type_, xp)
#     649     return xp.finfo(type_)
#     650 except (ValueError, TypeError):
# --> 651     return xp.finfo(type_.dtype)
#
# AttributeError: 'numpy.dtypes.ObjectDType' object has no attribute 'dtype'

# %%
ec_expression_numeric.iloc[:,1:].dtypes.unique()
# Out:
# array([dtype('float64')], dtype=object)

# %%
print(type(ec_expression_numeric[control_ids[0]].iloc[0]))
print(type(ec_expression_numeric[alz_ids[0]].iloc[0]))
# Out:
# <class 'numpy.float64'>
# <class 'numpy.float64'>

# %%
row = ec_expression_numeric.iloc[0]

control_values = row[control_ids]
alz_values = row[alz_ids]

print(control_values.dtype)
print(alz_values.dtype)

print(control_values.head())
# Out:
# object
# object
# GSM119615     693.9733
# GSM119616    807.14514
# GSM119617     1722.625
# GSM119618    1668.0575
# GSM119619    2231.2969
# Name: 0, dtype: object

# %%
from scipy.stats import ttest_ind

p_values = []

for _, row in ec_expression_numeric.iterrows():

    control_values = row[control_ids].astype(float)
    alz_values = row[alz_ids].astype(float)

    _, p = ttest_ind(
        control_values,
        alz_values,
        equal_var=False
    )

    p_values.append(p)

gene_stats["p_value"] = p_values

print("Done")
# Out:
# Done

# %%
from scipy.stats import ttest_ind

p_values = []

for _, row in ec_expression_numeric.iterrows():

    control_values = row[control_ids].astype(float)
    alz_values = row[alz_ids].astype(float)

    _, p = ttest_ind(
        control_values,
        alz_values,
        equal_var=False
    )

    p_values.append(p)

gene_stats["p_value"] = p_values

print("Done")
# Out:
# Done

# %%
gene_stats.sort_values("p_value").head(20)
# Out:
#                Gene  Control_Mean  Alzheimer_Mean    Log2FC       p_value
# 27941     218657_at    428.454850       85.520190 -2.311398  1.499903e-08
# 31089     221809_at    193.715840       32.312868 -2.547219  1.601099e-08
# 34786     225529_at    625.758232      206.577730 -1.594257  4.942816e-08
# 18777     209364_at    359.934277       63.217160 -2.490705  5.174607e-08
# 24529     215235_at   8953.051492     2246.010000 -1.994534  5.520249e-08
# 54210      34726_at   1382.252054      423.549200 -1.704060  6.171260e-08
# 4420   1558796_a_at   6105.214654      984.584700 -2.631227  7.579095e-08
# 30864     221582_at    389.735185      165.159940 -1.233619  1.160262e-07
# 31069   221789_x_at    294.038130       47.162670 -2.614914  1.274147e-07
# 18507   209093_s_at    321.073322       79.816910 -1.994660  1.771211e-07
# 19976   210589_s_at    971.094821      172.246220 -2.488273  1.976425e-07
# 25274   215982_s_at    533.557361      142.622360 -1.896064  2.269191e-07
# 41089     231835_at   2395.240887      287.642430 -3.053418  2.651981e-07
# 45543     236294_at   1695.211938      425.539200 -1.991566  3.680598e-07
# 27337   218052_s_at    468.282337      120.252380 -1.952443  3.946322e-07
# 41223     231969_at   5707.342538     1273.151900 -2.163535  4.130960e-07
# 21036   211715_s_at    420.062724      124.834680 -1.742506  4.168629e-07
# 14031     204584_at   5953.833200     1248.416700 -2.252806  4.469211e-07
# 12038   202590_s_at    292.563187       76.176420 -1.927439  4.642417e-07
# 23141     213841_at   5226.083608     1982.332000 -1.398080  5.892176e-07

# %%
gene_stats.sort_values("p_value").head(20)
# Out:
#                Gene  Control_Mean  Alzheimer_Mean    Log2FC       p_value
# 27941     218657_at    428.454850       85.520190 -2.311398  1.499903e-08
# 31089     221809_at    193.715840       32.312868 -2.547219  1.601099e-08
# 34786     225529_at    625.758232      206.577730 -1.594257  4.942816e-08
# 18777     209364_at    359.934277       63.217160 -2.490705  5.174607e-08
# 24529     215235_at   8953.051492     2246.010000 -1.994534  5.520249e-08
# 54210      34726_at   1382.252054      423.549200 -1.704060  6.171260e-08
# 4420   1558796_a_at   6105.214654      984.584700 -2.631227  7.579095e-08
# 30864     221582_at    389.735185      165.159940 -1.233619  1.160262e-07
# 31069   221789_x_at    294.038130       47.162670 -2.614914  1.274147e-07
# 18507   209093_s_at    321.073322       79.816910 -1.994660  1.771211e-07
# 19976   210589_s_at    971.094821      172.246220 -2.488273  1.976425e-07
# 25274   215982_s_at    533.557361      142.622360 -1.896064  2.269191e-07
# 41089     231835_at   2395.240887      287.642430 -3.053418  2.651981e-07
# 45543     236294_at   1695.211938      425.539200 -1.991566  3.680598e-07
# 27337   218052_s_at    468.282337      120.252380 -1.952443  3.946322e-07
# 41223     231969_at   5707.342538     1273.151900 -2.163535  4.130960e-07
# 21036   211715_s_at    420.062724      124.834680 -1.742506  4.168629e-07
# 14031     204584_at   5953.833200     1248.416700 -2.252806  4.469211e-07
# 12038   202590_s_at    292.563187       76.176420 -1.927439  4.642417e-07
# 23141     213841_at   5226.083608     1982.332000 -1.398080  5.892176e-07

# %%
control_values = row[control_ids].astype(float)
alz_values = row[alz_ids].astype(float)

# %%
len(p_values)
# Out:
# 54675

# %%
ec_numeric = ec_expression_numeric.set_index("ID_REF")

gene_variance = ec_numeric.var(axis=1)

top_genes = gene_variance.sort_values(
    ascending=False
).head(2000).index

ec_top = ec_numeric.loc[top_genes]

ec_top.shape
# Out:
# (2000, 23)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

X_ec = ec_top.T

X_scaled = StandardScaler().fit_transform(X_ec)

pca = PCA(n_components=2)

X_pca_ec = pca.fit_transform(X_scaled)

print(pca.explained_variance_ratio_)
# Out:
# [0.65841977 0.15880751]

# %%
import matplotlib.pyplot as plt

pca_df = pd.DataFrame({
    "PC1": X_pca_ec[:,0],
    "PC2": X_pca_ec[:,1],
    "Disease": ec_samples["Disease"].values
})

plt.figure(figsize=(8,6))

for disease in pca_df["Disease"].unique():

    subset = pca_df[pca_df["Disease"] == disease]

    plt.scatter(
        subset["PC1"],
        subset["PC2"],
        label=disease
    )

plt.xlabel("PC1")
plt.ylabel("PC2")
plt.title("EC Samples PCA (Top 2000 Variable Genes)")
plt.legend()
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import LeaveOneOut, cross_val_score

X_ml = ec_top.T

y_ml = (
    ec_samples["Disease"]
    .map({"Control":0, "Alzheimer":1})
    .values
)

rf = RandomForestClassifier(
    n_estimators=500,
    random_state=42
)

loo = LeaveOneOut()

scores = cross_val_score(
    rf,
    X_ml,
    y_ml,
    cv=loo,
    scoring="accuracy"
)

print("Accuracy:", scores.mean())
# Out:
# Accuracy: 0.9130434782608695

# %%
rf.fit(X_ml, y_ml)

feature_importance = pd.DataFrame({
    "Gene": ec_top.index,
    "Importance": rf.feature_importances_
})

feature_importance = feature_importance.sort_values(
    "Importance",
    ascending=False
)

feature_importance.head(20)
# Out:
#               Gene  Importance
# 724      229724_at    0.020000
# 929    200746_s_at    0.014329
# 1738     227847_at    0.014000
# 1443     211950_at    0.014000
# 464      228067_at    0.012329
# 263    212473_s_at    0.012000
# 381      225098_at    0.012000
# 70     215116_s_at    0.012000
# 351    201828_x_at    0.012000
# 1048   212852_s_at    0.011516
# 1623      36994_at    0.010484
# 563      218175_at    0.010000
# 1509      49077_at    0.010000
# 599   1553422_s_at    0.008359
# 197    227186_s_at    0.008000
# 1484     232226_at    0.008000
# 1879   212281_s_at    0.008000
# 383    213689_x_at    0.008000
# 1308     213547_at    0.008000
# 313      212843_at    0.008000

# %%
feature_importance.head(50)
# Out:
#               Gene  Importance
# 724      229724_at    0.020000
# 929    200746_s_at    0.014329
# 1738     227847_at    0.014000
# 1443     211950_at    0.014000
# 464      228067_at    0.012329
# 263    212473_s_at    0.012000
# 381      225098_at    0.012000
# 70     215116_s_at    0.012000
# 351    201828_x_at    0.012000
# 1048   212852_s_at    0.011516
# 1623      36994_at    0.010484
# 563      218175_at    0.010000
# 1509      49077_at    0.010000
# 599   1553422_s_at    0.008359
# 197    227186_s_at    0.008000
# 1484     232226_at    0.008000
# 1879   212281_s_at    0.008000
# 383    213689_x_at    0.008000
# 1308     213547_at    0.008000
# 313      212843_at    0.008000
# 954     1564841_at    0.008000
# 445      206140_at    0.008000
# 1846     219463_at    0.008000
# 449      204000_at    0.007671
# 416    213869_x_at    0.007357
# 1381     231783_at    0.007352
# 608    200822_x_at    0.006363
# 851      204454_at    0.006000
# 1793     212664_at    0.006000
# 620     1558795_at    0.006000
# 1713   202552_s_at    0.006000
# 1704   209609_s_at    0.006000
# 624      205103_at    0.006000
# 270      215235_at    0.006000
# 1756      41047_at    0.006000
# 534      231969_at    0.006000
# 863    208851_s_at    0.006000
# 170    221798_x_at    0.006000
# 1376   201613_s_at    0.006000
# 346    221984_s_at    0.006000
# 804    213011_s_at    0.006000
# 1542     200083_at    0.006000
# 302    217727_x_at    0.006000
# 1400   203431_s_at    0.006000
# 1937     242476_at    0.006000
# 327      212358_at    0.006000
# 301      217719_at    0.005678
# 791      223500_at    0.005613
# 404       47560_at    0.005398
# 1371   212520_s_at    0.005359

# %%
from scipy.stats import ttest_ind
import numpy as np

results = []

for gene in ec_top.index:

    control = ec_top.loc[gene, control_ids].astype(float)
    alz = ec_top.loc[gene, alz_ids].astype(float)

    stat, p = ttest_ind(
        control,
        alz,
        equal_var=False
    )

    log2fc = np.log2(
        (alz.mean() + 1) /
        (control.mean() + 1)
    )

    results.append([
        gene,
        log2fc,
        p
    ])

de_results = pd.DataFrame(
    results,
    columns=[
        "Gene",
        "Log2FC",
        "p_value"
    ]
)

de_results.sort_values("p_value").head(20)
# Out:
#               Gene    Log2FC       p_value
# 270      215235_at -1.994534  5.520249e-08
# 417   1558796_a_at -2.631227  7.579095e-08
# 1522     231835_at -3.053418  2.651981e-07
# 534      231969_at -2.163535  4.130960e-07
# 475      204584_at -2.252806  4.469211e-07
# 778      213841_at -1.398080  5.892176e-07
# 276    210111_s_at -1.472909  6.923283e-07
# 445      206140_at -1.922450  1.579663e-06
# 70     215116_s_at -2.739247  1.693364e-06
# 563      218175_at -2.172186  2.499480e-06
# 1219     227440_at -1.768607  2.719815e-06
# 464      228067_at -2.535814  2.730904e-06
# 1506   223611_s_at -1.954913  2.922219e-06
# 997      227984_at -1.817698  2.954223e-06
# 597   1569872_a_at -1.521142  3.135328e-06
# 1305     238893_at -1.416243  3.148747e-06
# 1954   205109_s_at -1.108726  3.769263e-06
# 311       56256_at -1.491784  3.814252e-06
# 263    212473_s_at -1.861488  4.949848e-06
# 1738     227847_at -1.497814  5.006042e-06

# %%
import matplotlib.pyplot as plt
import numpy as np

de_results["minus_log10_p"] = -np.log10(de_results["p_value"])

plt.figure(figsize=(10,6))

plt.scatter(
    de_results["Log2FC"],
    de_results["minus_log10_p"],
    alpha=0.5
)

plt.xlabel("Log2 Fold Change")
plt.ylabel("-log10(p-value)")
plt.title("Volcano Plot: EC Alzheimer vs Control")

plt.show()
